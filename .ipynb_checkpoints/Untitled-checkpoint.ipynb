# %%
# %matplotlib inline
from technical_report import get_report
import datetime

# %%
start = datetime.datetime(2014, 8, 29)
end = datetime.datetime(2015, 8, 29)
symbols = ['0400.HK', '1717.HK']

# %%
get_report(symbols, start, end)
# Out:
# The historical prices compared with HSI index.
# All stock prices are normalized to 1 at the beginning of the time for easier comparison.
# <IPython.core.display.HTML object>
# The Bollinger Bands for both stocks with 20-day moving average and 1 standard deviation.
# Daily returns throughout the year plotted as histograms.
# White dashed line denotes the mean and the red ones are standard deviations.
# Daily returns of each stock against which of the HSI index.
# Beta, alpha and correlation of each stock.
# <IPython.core.display.HTML object>
# The Bollinger Bands for both stocks with 20-day moving average and 1 standard deviation.
# Daily returns throughout the year plotted as histograms.
# White dashed line denotes the mean and the red ones are standard deviations.
# Daily returns of each stock against which of the HSI index.
# Beta, alpha and correlation of each stock.

# %%
# Out:
# '<IPython.core.display.HTML object>'
